# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Task:
#
# 1. Load your csvs into this notebook.
# 2. Clean the files
# 3. Output them
#
#
# Stretch:
# 1. Add some data engineering metrics you want to track.
# 3. Output the files to a local SSMS databas with the data engineering metrics.
# 2. Ask Nirosh.
